# %%
import pandas as pd

# %%
dfmerge = pd.read_excel("Hotel Analytics.xlsx","Merge")

# %%
dfmerge
# Out:
#      Room Type  Month  NumberOfRooms  PlanRoom  PlanFood  PlanBar  PlanTotal  \
# 0   ClubDeluxe      1             28       NaN       NaN      NaN        NaN
# 1   ClubDeluxe      2             28       NaN       NaN      NaN        NaN
# 2   ClubDeluxe      3             28       NaN       NaN      NaN        NaN
# 3   ClubDeluxe      4             28       NaN       NaN      NaN        NaN
# 4   ClubDeluxe      5             28       NaN       NaN      NaN        NaN
# ..         ...    ...            ...       ...       ...      ...        ...
# 67    OneSuite      8              6       NaN       NaN      NaN        NaN
# 68    OneSuite      9              6       NaN       NaN      NaN        NaN
# 69    OneSuite     10              6       NaN       NaN      NaN        NaN
# 70    OneSuite     11              6       NaN       NaN      NaN        NaN
# 71    OneSuite     12              6       NaN       NaN      NaN        NaN
#
# ...

# %%
dfactuals = pd.read_excel("Hotel Analytics_v2.xlsx","Actuals")

# %%
dfactuals
# Out:
#        Visit ID  Month  Room ID           Room type  Room price  \
# 0             1      1        1  Superior King Room         150
# 1             2      1        1  Superior King Room         150
# 2             3      1        1  Superior King Room         150
# 3             4      1        1  Superior King Room         150
# 4             5      1        1  Superior King Room         150
# ...         ...    ...      ...                 ...         ...
# 13581     13582     12      200   One-Bedroom Suite         900
# 13582     13583     12      200   One-Bedroom Suite         900
# 13583     13584     12      200   One-Bedroom Suite         900
# 13584     13585     12      200   One-Bedroom Suite         900
# 13585     13586     12      200   One-Bedroom Suite         900
#
#        Loyalty status  Actual Days Stay  Concern Concern description  \
# 0                   0                 3        0                 NaN
# ...

# %%
dfactuals_agg = dfactuals[["Month","Room type","Revenue room","Revenue Food","Revenue Bevarages","Revenue Total"]]
dfactuals_agg_series = dfactuals_agg.groupby(["Room type","Month"],as_index=False).agg("sum")

# %%
dfactuals_agg_series
# Out:
#                 Room type  Month  Revenue room  Revenue Food  \
# 0   Club Deluxe King Room      1        205200         30271
# 1   Club Deluxe King Room      2        245250         32164
# 2   Club Deluxe King Room      3        290800         41080
# 3   Club Deluxe King Room      4        255200         25222
# 4   Club Deluxe King Room      5        288000         16293
# ..                    ...    ...           ...           ...
# 67     Superior King Room      8        261000         59086
# 68     Superior King Room      9        156520         34636
# 69     Superior King Room     10        332850        126851
# 70     Superior King Room     11        205350         52867
# 71     Superior King Room     12        277100         81952
#
#     Revenue Bevarages  Revenue Total
# 0               21888         257359
# 1               26281         303695
# 2               41386         373266
# 3               34999         315421
# 4               31365         335658
# ...

# %%
dfactuals_agg_series.to_excel("actual agg.xlsx",index=False)
