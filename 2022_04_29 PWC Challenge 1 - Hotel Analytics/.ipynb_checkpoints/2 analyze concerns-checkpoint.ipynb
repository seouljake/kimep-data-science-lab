# %%
import pandas as pd

# %%
dfactuals = pd.read_excel("Hotel Analytics.xlsx","Actuals")

# %%
dfactuals[dfactuals["Concern"]==1]
# Out:
#        Visit ID  Month  Room ID           Room type  Room price  \
# 1             2      1        1  Superior King Room         150
# 5             6      1        1  Superior King Room         150
# 28           29      5        1  Superior King Room         130
# 35           36      7        1  Superior King Room         150
# 37           38      7        1  Superior King Room         150
# ...         ...    ...      ...                 ...         ...
# 13566     13567     10      200   One-Bedroom Suite         800
# 13574     13575     11      200   One-Bedroom Suite         800
# 13575     13576     11      200   One-Bedroom Suite         800
# 13578     13579     12      200   One-Bedroom Suite         900
# 13579     13580     12      200   One-Bedroom Suite         900
#
#        Loyalty status  Actual Days Stay  Concern  \
# 1                   0                 4        1
# 5                   0                 1        1
# ...
