# %%
# import pandas
import pandas as pd
pd.__version__
# Out:
# '1.2.0'

# %%
filename = "worldcities.csv"

#file=open(filename)
file = open(filename,encoding="utf-8")

# %%
#for row in file:
#    print(row)
file
# Out:
# <_io.TextIOWrapper name='worldcities.csv' mode='r' encoding='utf-8'>

# %%
# read csv file into list
dat=[]
for row in file:
    dat.append(row)

# %%
len(dat)
# Out:
# 42906

# %%
len(dat[1])
# Out:
# 98

# %%
dat[1]
# Out:
# '"Tokyo","Tokyo","35.6839","139.7744","Japan","JP","JPN","Tōkyō","primary","39105000","1392685764"\n'

# %%
dat[1].split(",")
# Out:
# ['"Tokyo"',
#  '"Tokyo"',
#  '"35.6839"',
#  '"139.7744"',
#  '"Japan"',
#  '"JP"',
#  '"JPN"',
#  '"Tōkyō"',
#  '"primary"',
#  '"39105000"',
#  '"1392685764"\n']

# %%
# https://www.dataquest.io/blog/pandas-cheat-sheet/

# %%
# import into pandas
df.raw=pd.read_csv(filename)

# %%
df
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...            ...          ...      ...       ...          ...  ...  ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia   RU  RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia   RU  RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                                      admin_name  capital  population  \
# ...

# %%
# output data

df.to_csv('output.csv')

# %%
# attributes

# https://pythontic.com/pandas/dataframe-attributes/introduction

df.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
# https://www.dataquest.io/blog/pandas-cheat-sheet/

# %%
# view data

#df.head(n) | First n rows of the DataFrame
#df.tail(n) | Last n rows of the DataFrame
#df.shape | Number of rows and columns
#df.info() | Index, Datatype and Memory information
#df.describe() | Summary statistics for numerical columns
#s.value_counts(dropna=False) | View unique values and counts
#df.apply(pd.Series.value_counts) | Unique values and counts for all columns

# %%
df.head(10)
# Out:
#           city   city_ascii      lat       lng      country iso2 iso3  \
# 0        Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1      Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2        Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3       Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4    São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# 5        Seoul        Seoul  37.5600  126.9900  South Korea   KR  KOR
# 6       Mumbai       Mumbai  19.0758   72.8775        India   IN  IND
# 7     Shanghai     Shanghai  31.1667  121.4667        China   CN  CHN
# 8  Mexico City  Mexico City  19.4333  -99.1333       Mexico   MX  MEX
# 9    Guangzhou    Guangzhou  23.1288  113.2590        China   CN  CHN
#
#          admin_name  capital  population          id
# 0             Tōkyō  primary  39105000.0  1392685764
# 1           Jakarta  primary  35362000.0  1360771077
# ...

# %%
# selection

#df[col] | Returns column with label col as Series
#df[[col1, col2]] | Returns columns as a new DataFrame
#s.iloc[0] | Selection by position
#s.loc['index_one'] | Selection by index
#df.iloc[0,:] | First row
#df.iloc[0,0] | First element of first column

# %%
# Out:
#   File "<ipython-input-39-141c20e2d6bf>", line 1
#     df[row where "city"=="Mumbai"]
#                ^
# SyntaxError: invalid syntax

# %%
# data cleaning

# df.columns = ['a','b','c'] | Rename columns
# pd.isnull() | Checks for null Values, Returns Boolean Arrray
# pd.notnull() | Opposite of pd.isnull()
# df.dropna() | Drop all rows that contain null values
# df.dropna(axis=1) | Drop all columns that contain null values
# df.dropna(axis=1,thresh=n) | Drop all rows have have less than n non null values
# df.fillna(x) | Replace all null values with x
# s.fillna(s.mean()) | Replace all null values with the mean (mean can be replaced with almost any function from the statistics module)
# s.astype(float) | Convert the datatype of the series to float
# s.replace(1,'one') | Replace all values equal to 1 with ‘one’
# s.replace([1,3],['one','three']) | Replace all 1 with ‘one’ and 3 with ‘three’
# df.rename(columns=lambda x: x + 1) | Mass renaming of columns
# df.rename(columns={'old_name': 'new_ name'}) | Selective renaming
# df.set_index('column_one') | Change the index
# df.rename(index=lambda x: x + 1) | Mass renaming of index

# %%
df.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
df.columns = ['city', 'city_ascii', 'latitude', 'longitude', 'country', 'iso2', 'iso3',
       'admin_name', 'capital', 'population', 'id']

# %%
df.columns
# Out:
# Index(['city', 'city_ascii', 'latitude', 'longitude', 'country', 'iso2',
#        'iso3', 'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
df
# Out:
#               city   city_ascii  latitude  longitude      country iso2 iso3  \
# 0            Tokyo        Tokyo   35.6839   139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta   -6.2146   106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi   28.6667    77.2167        India   IN  IND
# 3           Manila       Manila   14.6000   120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo  -23.5504   -46.6339       Brazil   BR  BRA
# ...            ...          ...       ...        ...          ...  ...  ...
# 42900       Tukchi       Tukchi   57.3670   139.5000       Russia   RU  RUS
# 42901        Numto        Numto   63.6667    71.3333       Russia   RU  RUS
# 42902         Nord         Nord   81.7166   -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut   62.5333   -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik   74.0165   111.5100       Russia   RU  RUS
#
# ...

# %%
# filter, sort and group by

# df[df[col] > 0.5] | Rows where the column col is greater than 0.5
# df[(df[col] > 0.5) & (df[col] < 0.7)] | Rows where 0.7 > col > 0.5
# df.sort_values(col1) | Sort values by col1 in ascending order
# df.sort_values(col2,ascending=False) | Sort values by col2 in descending order
# df.sort_values([col1,col2],ascending=[True,False]) | Sort values by col1 in ascending order then col2 in descending order
# df.groupby(col) | Returns a groupby object for values from one column
# df.groupby([col1,col2]) | Returns groupby object for values from multiple columns
# df.groupby(col1)[col2] | Returns the mean of the values in col2, grouped by the values in col1 (mean can be replaced with almost any function from the statistics module)
# df.pivot_table(index=col1,values=[col2,col3],aggfunc=mean) | Create a pivot table that groups by col1 and calculates the mean of col2 and col3
# df.groupby(col1).agg(np.mean) | Find the average across all columns for every unique col1 group
# df.apply(np.mean) | Apply the function np.mean() across each column
# nf.apply(np.max,axis=1) | Apply the function np.max() across each row

# %%
df.groupby("country").count()
#df[df["population"]>10000000].sort_values("latitude")
# Out:
#                    city  city_ascii  latitude  longitude  iso2  iso3  \
# country
# Afghanistan          45          45        45         45    45    45
# Albania              51          51        51         51    51    51
# Algeria             157         157       157        157   157   157
# American Samoa        1           1         1          1     1     1
# Andorra               7           7         7          7     7     7
# ...                 ...         ...       ...        ...   ...   ...
# Wallis And Futuna     2           2         2          2     2     2
# West Bank             1           1         1          1     1     1
# Yemen                42          42        42         42    42    42
# Zambia               35          35        35         35    35    35
# Zimbabwe             26          26        26         26    26    26
#
#                    admin_name  capital  population   id
# country
# Afghanistan                45       41          40   45
# ...

# %%
# largest city above the artic circle

df.sort_values("latitude")
df[ df["latitude"]>66].sort_values("population")
# Out:
#                 city     city_ascii  latitude  longitude   country iso2 iso3  \
# 42904        Nordvik        Nordvik   74.0165   111.5100    Russia   RU  RUS
# 42283     Logashkino     Logashkino   70.8536   153.8744    Russia   RU  RUS
# 42282      Ambarchik      Ambarchik   69.6167   162.2833    Russia   RU  RUS
# 42279    Ust’-Olenëk    Ust'-Olenek   72.9855   119.8214    Russia   RU  RUS
# 42280       Zhilinda       Zhilinda   70.1333   113.9833    Russia   RU  RUS
# ...              ...            ...       ...        ...       ...  ...  ...
# 10937        Vorkuta        Vorkuta   67.5000    64.0333    Russia   RU  RUS
# 4547   Novyy Urengoy  Novyy Urengoy   66.0847    76.6789    Russia   RU  RUS
# 3139         Norilsk        Norilsk   69.3333    88.2167    Russia   RU  RUS
# 2076        Murmansk       Murmansk   68.9667    33.0833    Russia   RU  RUS
# 848     Longyearbyen   Longyearbyen   78.2167    15.6333  Svalbard   XR  XSV
#
# ...

# %%
df1=df[df["population"].notnull()]
df1=df1[df1["population"]>10000]

# %%
df1[df1["latitude"]>66].sort_values("population",ascending=False)
# Out:
#                   city       city_ascii  latitude  longitude  country iso2  \
# 2076          Murmansk         Murmansk   68.9667    33.0833   Russia   RU
# 3139           Norilsk          Norilsk   69.3333    88.2167   Russia   RU
# 4547     Novyy Urengoy    Novyy Urengoy   66.0847    76.6789   Russia   RU
# 10937          Vorkuta          Vorkuta   67.5000    64.0333   Russia   RU
# 5745         Rovaniemi        Rovaniemi   66.5028    25.7285  Finland   FI
# 12379          Apatity          Apatity   67.5675    33.3933   Russia   RU
# 6000              Bodø             Bodo   67.2833    14.3833   Norway   NO
# 12801      Severomorsk      Severomorsk   69.0692    33.4167   Russia   RU
# 6138         Salekhard        Salekhard   66.5333    66.6333   Russia   RU
# 13983      Monchegorsk      Monchegorsk   67.9394    32.9156   Russia   RU
# 6488            Tromsø           Tromso   69.6546    18.9637   Norway   NO
# ...

# %%
# find the country that has 5+ cities of population > 10,000,000

cc=df[df["population"]>10000000].groupby("country").count()

# %%
cc
# Out:
#                   city  city_ascii  latitude  longitude  iso2  iso3  \
# country
# Argentina            1           1         1          1     1     1
# Bangladesh           1           1         1          1     1     1
# Brazil               2           2         2          2     2     2
# China               11          11        11         11    11    11
# Congo (Kinshasa)     1           1         1          1     1     1
# Egypt                1           1         1          1     1     1
# France               1           1         1          1     1     1
# India                5           5         5          5     5     5
# Indonesia            1           1         1          1     1     1
# Iran                 1           1         1          1     1     1
# Japan                2           2         2          2     2     2
# Mexico               1           1         1          1     1     1
# Nigeria              1           1         1          1     1     1
# ...

# %%
cc[cc["city"]>4]
# Out:
#          city  city_ascii  latitude  longitude  iso2  iso3  admin_name  \
# country
# China      11          11        11         11    11    11          11
# India       5           5         5          5     5     5           5
#
#          capital  population  id
# country
# China          8          11  11
# India          5           5   5
